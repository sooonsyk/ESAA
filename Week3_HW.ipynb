# %% [markdown]
# <a href="https://colab.research.google.com/github/sooonsyk/ESAA/blob/main/Week3_HW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**두잇 판다스 입문 p. 81 ~ 119**

# %% [markdown]
# ##**데이터 시각화가 필요한 이유**
# ###**앤스콤 4분할 그래프 살펴보기**
# - 데이터 시각화를 보여주는 전형적인 사례
# - 데이터를 시각화하지 않고 수치만 확인할 때 발생할 수 있는 함정을 보여주기 위해 만든 그래프
# ####**앤스콤이 지적한 함정과 데이터 시각화의 필요성**
# - 앤스콤 4분할 그래프를 구성하는 데이터 집합은 4개의 그룹으로 구성되어 있으며 모든 데이터 그룹은 x,y 열을 가짐
# - 이 4개의 데이터 그룹은 각각 평균, 분산과 같은 수칫값이나 상관관계, 회귀선이 같다는 특징이 있음
#
#  -> 데이터 그룹들의 데이터는 모두 같을 것이라고 착각할 수 있음, 시각화하면 서로 다르다는 것 알 수 있음

# %%
import seaborn as sns

anscombe = sns.load_dataset("anscombe")
print(anscombe)
print(type(anscombe))
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset_1 = anscombe[anscombe['dataset'] == 'I']

# %%
plt.plot(dataset_1['x'], dataset_1['y']) #기본적으로 선으로 그래프 그림

# %%
plt.plot(dataset_1['x'], dataset_1['y'], 'o') #점으로 그래프 그리려면 세번째 인자로 'o' 전달

# %% [markdown]
# ###**앤스콤 데이터 집합 모두 사용해 그래프 만들기**
# ####**matplotlib 라이브러리로 그래프 그리기**
# 1. 전체 그래프가 위치할 기본 틀 만들기
# 2. 그래프를 그려 넣을 그래프 격자 만들기
# 3. 격자에 그래프 하나씩 추가, 격자에 그래프가 추가되는 순서는 왼쪽에서 오른쪽
# 4. 만약 격자의 첫번째 행이 꽉 차면 두번째 행에 그래프를 그려 넣음

# %%
dataset_2 = anscombe[anscombe['dataset'] == 'II']
dataset_3 = anscombe[anscombe['dataset'] == 'III']
dataset_4 = anscombe[anscombe['dataset'] == 'IV']

# %%
fig = plt.figure() #그래프 격자가 위치할 기본 틀
# add_subplot 메서드로 그래프 격자 그림, 첫번째 인자에는 그래프 기본 틀의 행 크기를, 두번째 인자에는 그래프 기본 틀의 열 크기를 지정
axes1 = fig.add_subplot(2,2,1)
axes2 = fig.add_subplot(2,2,2)
axes3 = fig.add_subplot(2,2,3)
axes4 = fig.add_subplot(2,2,4)

# %%
#plot 메서드에 데이터 전달하여 그래프 그림
axes1.plot(dataset_1['x'], dataset_1['y'],'o')
axes2.plot(dataset_2['x'], dataset_2['y'],'o')
axes3.plot(dataset_3['x'], dataset_3['y'],'o')
axes4.plot(dataset_4['x'], dataset_4['y'],'o')

fig  # 그래프 확인하려면 반드시 입력해야함, 점의 색은 매번 실행할 때마다 달라질 수 있음

# %%
#그래프 격자에 제목 추가
axes1.set_title("dataset_1")
axes2.set_title("dataset_2")
axes3.set_title("dataset_3")
axes4.set_title("dataset_4")

fig

# %%
#기본 틀에 제목 추가
fig.suptitle("Anscombe Data")
fig

# %%
# 각 그래프의 이름과 숫자가 겹쳐 보임
fig.tight_layout()
fig

# %% [markdown]
# ##**matplotlib 라이브러리 자유자재로 사용하기**
# ###**기초 그래프 그리기**
# - seaborn 라이브러리의 tips data : 어떤 식당에서 팁을 지불한 손님의 정보를 모아둔 것

# %%
tips = sns.load_dataset("tips")
print(tips.head())
print(type(tips))
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# - 히스토그램 : 데이터프레임의 열 데이터 분포와 빈도를 살펴보는 용도로 자주 사용하는 그래프
# - 일변량 그래프 : 변수를 하나만 사용해서 그린 그래프

# %%
fig = plt.figure()
axes1 = fig.add_subplot(1,1,1)

# %%
axes1.hist(tips['total_bill'], bins=10)  #x축의 간격 bins 인잣값으로 조절
axes1.set_title('Histogram of Total Bill')
axes1.set_xlabel('Frequency')
axes1.set_ylabel('Total Bill')

fig

# %% [markdown]
# - 산점도 : 변수 2개를 사용해서 만드는 그래프
# - 이변량 그래프 : 변수 2개 사용해서 그리는 그래프

# %%
scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1,1,1)
axes1.scatter(tips['total_bill'],tips['tip'])
axes1.set_title('Scatterplot of Total Bill vs Tip')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %% [markdown]
# - 박스 그래프 : 이산형 변수와 연속형 변수를 함께 사용하는 그래프
#   - 이산형 변수 : 명확하게 구분되는 값
#   - 연속형 변수 : 명확하게 셀 수 없는 범위의 값

# %%
boxplot = plt.figure()
axes1 = boxplot.add_subplot(1,1,1)

axes1.boxplot([tips[tips['sex'] == 'Female']['tip'],
               tips[tips['sex'] == 'Male']['tip']],   #성별이 Female인 데이터와 Male인 데이터에서 tip 열 데이터만 추출하여 리스트에 담아 전달
               labels = ['Female','Male'])
axes1.set_xlabel('Sex')
axes1.set_ylabel('Tip')
axes1.set_title('Boxplot of Tips by Sex')
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))
# Text(0.5, 1.0, 'Boxplot of Tips by Sex')

# %% [markdown]
# ###**다변량 그래프 그리기**
# - 다변량 그래프 : 3개 이상의 변수를 사용한 그래프
# ####**다변량 그래프가 필요한 이유**

# %%
#scatter_plot 에 성별을 새 변수로 추가, 성별은 산점도 그래프에서 색상으로 구분
#Female, Male 과 같은 문자열은 산점도 그래프의 색상을 지정하는 값으로 사용할 수 없음, 0,1과 같은 정수를 사용해야 함
#문자열을 정수로 치환하는 함수
def recode_sex(sex):
  if sex == 'Female':
    return 0
  else:
    return 1

# %%
#recode_sex 메서드가 반환한 값을 데이터 프레임에 추가
tips['sex_color'] = tips['sex'].apply(recode_sex) #sex열에 recode_sex 함수를 브로드캐스팅하기 위해 apply메서드 사용

# %%
scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1,1,1)
axes1.scatter(x = tips['total_bill'],
              y = tips['tip'],
              s = tips['size'] * 10,  #테이블당 인원수 추가, 점의 크기로 표현
              c = tips['sex_color'],  # s는 점의 사이즈, c 는 점의 색상
              alpha =  0.5)           #점의 투명도
axes1.set_title('Total Bill vs Tip Colored by Sex and Sized by Size')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %% [markdown]
# ##**seaborn 라이브러리 자유자재로 사용하기**
# - seaborn 라이브러리를 활용하면 matplotlib보다 좀 더 화려한 그래프 그릴 수 있음

# %%
tips = sns.load_dataset("tips")

# %%
ax = plt.subplots()  # 기본 틀 만들기
ax = sns.distplot(tips['total_bill']) # 히스토그램
ax.set_title('Total Bill Histogram with Density Plot')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Total Bill Histogram with Density Plot')

# %%
ax = plt.subplots() 
ax = sns.distplot(tips['total_bill'], kde = False) #distplot 메서드 사용하면 히스토그램 밀집도 그래프 같이 그림, 밀집도 제외하고 싶으면 kde=False로 설정 
ax.set_title('Total Bill Histogram')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Frequency')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Frequency')

# %%
ax = plt.subplots() 
ax = sns.distplot(tips['total_bill'], hist = False) #밀집도 그래프만 나타내려면 hist 인자를 False로 지정
ax.set_title('Total Bill Density')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Unit Probability')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Unit Probability')

# %% [markdown]
# - 양탄자 그래프 : 그래프의 축에 동일한 길이의 직선을 붙여 데이터의 밀집 정도를 표현한 그래프

# %%
#여러 그래프 한 번에 출력
ax = plt.subplots()
ax = sns.distplot(tips['total_bill'], rug=True) #rug 그래프 추가
ax.set_title('Total Bill Histogram with Density and Rug Plot')
ax.set_xlabel('Total Bill')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 0, 'Total Bill')

# %% [markdown]
# - count 그래프 : 이산값을 나타낸 그래프

# %%
ax = plt.subplots()
ax = sns.countplot('day', data=tips)
ax.set_title('Count of days')
ax.set_xlabel('Day of the Week')
ax.set_ylabel('Frequency')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ####**다양한 종류의 이변량 그래프 그리기**
# -: seaborn 라이브러리로 산점도 그래프 그리기
# - regplot 메서드 사용 - 산점도 그래프와 회귀선 함께, 회귀선 제거하려면 fit_reg = False

# %%
ax = plt.subplots()
ax = sns.regplot(x='total_bill', y='tip', data=tips)
ax.set_title('Scatterplot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
ax = plt.subplots()
ax = sns.regplot(x='total_bill', y='tip', data=tips, fit_reg=False)
ax.set_title('Scatterplot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %% [markdown]
#   - jointplot 메서드 - 산점도 그래프와 히스토그램 한 번에

# %%
joint = sns.jointplot(x='total_bill', y='tip', data=tips)
joint.set_axis_labels(xlabel='Total Bill',ylabel='Tip')
joint.fig.suptitle('Joint Plot of Total Bill and Tip', fontsize=10, y=1.03) # y : The y location of the text in figure coordinates.
# Out:
# Text(0.5, 1.03, 'Joint Plot of Total Bill and Tip')

# %% [markdown]
# - 산점도 그래프는 점이 겹쳐 보일 경우 점을 구분하기 어려움, 육각 그래프를 사용하면 그래프의 데이터를 구분하기 쉬움
# - 육각 그래프 : 2차원 표면에 육각형으로 데이터를 쌓아 표현하는 그래프, 특정 데이터의 개수가 많으면 진해짐
#   - jointplot 메서드 그대로 사용, kind 인잣값을 hex로 지정

# %%
hexbin = sns.jointplot(x='total_bill',y='tip',data=tips,kind='hex')
hexbin.set_axis_labels(xlabel='Total Bill', ylabel='Tip')
hexbin.fig.suptitle('Hexbin Joint Plot of Total Bill and Tip', fontsize=10, y=1.03)
# Out:
# Text(0.5, 1.03, 'Hexbin Joint Plot of Total Bill and Tip')

# %% [markdown]
# - 이차원 밀집도 그리기
# - kdeplot 메서드 사용

# %%
ax = plt.subplots()
ax = sns.kdeplot(data = tips['total_bill'],
                 data2 = tips['tip'],
                 shade = True) #그래프에 음영효과
ax.set_title('Kernel Density Plot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:1681: FutureWarning: Use `x` and `y` rather than `data` `and `data2`
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Tip')

# %% [markdown]
# - 바그래프 그리기 - 지정한 변수의 평균을 계산하여 그릴 수 있음

# %%
#시간에 따라 지불한 비용의 평균
ax = plt.subplots()
ax = sns.barplot(x='time', y='total_bill', data=tips)
ax.set_title('Bar plot of average total bill for time of day')
ax.set_xlabel('Time of day')
ax.set_ylabel('Average total bill')
# Out:
# Text(0, 0.5, 'Average total bill')

# %% [markdown]
# -박스 그래프 그리기
#   - 박스 그래프는 다양한 통계 수치를 확인하기 위해 자주 사용하는 그래프지만 데이터 분산이 모호하게 표현됨, 이런 경우 박스 그래프에 커널 밀도를 측정한 바이올린 그래프를 사용

# %%
ax = plt.subplots()
ax = sns.boxplot(x='time', y='total_bill', data=tips)
ax.set_title('Boxplot of total bill by time of day')
ax.set_xlabel('Time of day')
ax.set_ylabel('Total Bill')
# Out:
# Text(0, 0.5, 'Total Bill')

# %%
ax = plt.subplots()
ax = sns.violinplot(x='time', y='total_bill', data=tips)
ax.set_title('Violin plot of total bill by time of day')
ax.set_xlabel('Time of day')
ax.set_ylabel('Total Bill')
# Out:
# Text(0, 0.5, 'Total Bill')

# %% [markdown]
# - 관계 그래프 그리기 - 지금까지 설명한 그래프 종합
#   - 중복된 정보고 표현된다는 단점, 이런 경우 중복된 그래프가 그려지는 위치를 직접 지정하여 원하는 그래프로 교체

# %%
fig = sns.pairplot(tips)

# %%
pair_grid = sns.PairGrid(tips)
pair_grid = pair_grid.map_upper(sns.regplot)  #대각선을 기준으로 위쪽에 그릴 그래프 지정
pair_grid = pair_grid.map_lower(sns.kdeplot)  #대각선을 기준으로 아래쪽에 그릴 그래프 지정
pair_grid = pair_grid.map_diag(sns.distplot, rug=True)  # 대각선을 중심으로 그래프 그림
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# ####**다변량 그래프 그리기**
# - seaborn 라이브러리로 바이올린 그래프 그리기 - 색상 추가
#   - hue 인잣값으로 색상에 사용할 열 이름 추가

# %%
ax = plt.subplots()
ax = sns.violinplot(x='time', y='total_bill', hue='sex', data=tips, split=True)

# %% [markdown]
# - 산점도, 관계 그래프 그리기 - 색상 추가
#   - 방법 동일

# %%
scatter = sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', fit_reg=False)

# %%
fig = sns.pairplot(tips,hue='sex')

# %% [markdown]
# - 산점도 그래프의 크기와 모양 조절하기
#   - scatter_kws에 딕셔너리 형태로 인잣값 전달

# %%
scatter = sns.lmplot( x='total_bill', y='tip', data=tips, fit_reg=False, hue='sex', scatter_kws={'s': tips['size']*10})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-cb031548b6d1> in <module>()
# ----> 1 scatter = sns.lmplot( x='total_bill', y='tip', data=tips, fit_reg=False, hue='sex', scatter_kws={'s': tips['size']*10})
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %%
scatter = sns.lmplot(x='total_bill', y='tip', data=tips, fit_reg=False, hue='sex',markers=['o','x'], scatter_kws={'s':tips['size']*10})
#산점도 그래프의 점을 다른 기호로 표현하고 싶으면 markers 인잣값에 표현하고자 하는 기호를 리스트에 담아 전달
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-79-e9fbd6e13b8b> in <module>()
# ----> 1 scatter = sns.lmplot(x='total_bill', y='tip', data=tips, fit_reg=False, hue='sex',markers=['o','x'], scatter_kws={'s':tips['size']*10})
#       2 #산점도 그래프의 점을 다른 기호로 표현하고 싶으면 markers 인잣값에 표현하고자 하는 기호를 리스트에 담아 전달
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %% [markdown]
# - implot 메서드로 4개의 데이터 그룹에 대한 그래프 한 번에 그리기

# %%
anscombe_plot = sns.lmplot(x='x', y='y',data=anscombe, fit_reg=False)
#4개의 데이터 그룹이 한꺼번에 산점도 그래프로 그려짐

# %%
anscombe_plot = sns.lmplot(x='x', y='y', data=anscombe, fit_reg=False, col='dataset', col_wrap=2)
#그룹별로 그래프를 나누어 그리려면 lmplot메서드에 추가로 col, col_wrap인자를 설정해야 함, col에는 데이터 그룹을 구분할 열, col_wrap에는 그래프를 그릴 열의 최댓값 지정

# %% [markdown]
# - FacetGrid 클래스로도 그룹별 그래프를 그릴 수 있음
#   - 먼저 FacetGrid에 데이터프레임과 그룹을 구분할 열 이름을 전달하여 객체 생성, 그 다음에 map메서드에 그래프의 종류와 x축으로 지정할 열 이름을 순서대로 전달하며 히스토그램, 밀집도, 양탄자 그래프를 그릴 수 있음

# %%
facet = sns.FacetGrid(tips, col='time')
facet.map(sns.distplot, 'total_bill', rug=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
facet = sns.FacetGrid(tips, col='day', hue='sex')
facet = facet.map(plt.scatter, 'total_bill', 'tip')
facet = facet.add_legend()

# %%
facet = sns.FacetGrid(tips, col='time', row='smoker', hue='sex')  # time이랑 smoker가 각각 2개의 값을 가지니까 2행2열이 됨
facet.map(plt.scatter,'total_bill','tip')

# %% [markdown]
# ##**데이터프레임과 시리즈로 그래프 그리기**
# - 시리즈에 있는 plot 속성에 정의된 hist 메서드를 사용하면 바로 히스토그램 그릴 수 있음
#   - 투명도 조절하려면 hist 메서드의 alpha, bins, ax 인자 사용

# %%
ax = plt.subplots()
ax = tips['total_bill'].plot.hist()

# %%
fig, ax = plt.subplots()
ax = tips[['total_bill','tip']].plot.hist(alpha=0.5, bins=20, ax=ax)

# %%
ax = plt.subplots()
ax = tips['tip'].plot.kde()

# %%
fig, ax = plt.subplots()
ax = tips.plot.scatter(x='total_bill', y='tip', ax=ax)

# %%
fig, ax = plt.subplots()
ax = tips.plot.hexbin(x='total_bill', y='tip', ax=ax)

# %%
fig, ax = plt.subplots()
ax = tips.plot.hexbin(x='total_bill', y='tip', gridsize=10, ax=ax) #육각형 크기 변경

# %%
fig, ax = plt.subplots()
ax = tips.plot.box(ax=ax)
